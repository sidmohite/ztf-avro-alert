# %% [markdown]
# ### Working with Avro files
#
# Here are some examples of working with ZTF alerts stored as avro files.

# %%
import os
import io
import gzip
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from avro.datafile import DataFileReader, DataFileWriter
from avro.io import DatumReader, DatumWriter
import fastavro

from astropy.time import Time
from astropy.io import fits
import aplpy
# %matplotlib inline

# %% [markdown]
# A handful of sample alerts are available in the [ztf-avro-alert](https://github.com/ZwickyTransientFacility/ztf-avro-alert) repository, which also [documents](https://zwickytransientfacility.github.io/ztf-avro-alert/schema.html) the packet contents.

# %%
DATA_DIR = '../../ztf-avro-alert/data'

# %% [markdown]
# Let's count packets. Let's use a generator--we could eventually have millions of these alerts to look at!

# %%
def find_files(root_dir):
    for dir_name, subdir_list, file_list in os.walk(root_dir, followlinks=True):
        for fname in file_list:
            if fname.endswith('.avro'):
                yield dir_name+'/'+fname

# %%
list(find_files(DATA_DIR))
# Out:
# ['../../ztf-avro-alert/data/472263571115115011.avro',
#  '../../ztf-avro-alert/data/472263571115115000.avro',
#  '../../ztf-avro-alert/data/472263571115115014.avro',
#  '../../ztf-avro-alert/data/472263571115115008.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105682815010009.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107583415010028.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108980115010009.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581515015157.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107585415010011.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107583515015047.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107116215015067.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105683515015036.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105683015010112.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106592815015010.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105683615015019.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105203215015042.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108041115015073.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107115415010021.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106145315010017.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105683615010015.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107111315010369.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108041115010031.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107111315015134.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107580515010224.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107111315010407.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108041715015044.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107110515010033.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107580515010127.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107116315010036.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107110615010000.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108980715010006.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107112415010020.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105205715010004.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106143815010005.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107111415015293.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107114715010005.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106596315015052.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108985115015071.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105681315015038.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106141115010003.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581515010331.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106143715015009.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107111315010033.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106141415010019.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107111315010384.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107115415010049.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106142215010014.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581415010059.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581415010185.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106141215010016.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581515015081.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106140615010011.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108040115015015.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105684515010015.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107584615010001.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107583015010181.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107115615015022.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107111815010014.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106146015010029.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645097021615010002.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107113015010133.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108040215010012.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108046315015010.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107113015010200.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106146215010018.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107116215015004.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106593315010020.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105682615010040.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108042115015069.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105680915010010.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108041915010012.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105684915015002.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107110915015054.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106596215015000.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107115715010030.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107115315010010.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106144115015051.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105683215010011.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105680915010082.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581215010035.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107580615010027.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107113715015047.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107115415010008.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105683015010127.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107115915010102.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106145315015005.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107111515010108.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106144715015004.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107113715010020.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105685415010023.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106145015010005.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581415010172.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106592415010010.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581515010145.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107113015010138.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107112615015001.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107113615010013.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106595615010066.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581515010490.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107112215015037.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106593915015013.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581515010046.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107111315015038.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105681915015029.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107112115015104.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107583315015013.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105685415015004.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106591815010013.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107111215015037.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105685115010004.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107582915010046.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581215010034.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106146315015034.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581415015326.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107113315015012.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107115415010041.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108984115010006.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105202015010008.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581415015080.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107582415015101.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106144915010005.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106145315010031.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106595215010034.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106145415010014.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107110715010003.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106142115010001.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581415015363.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107585015010000.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106590515015035.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581215010130.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107585315015060.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106595715015047.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108042215010021.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107112215010011.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645098002915015031.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581515010360.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107114715015219.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108045915010026.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107115115015032.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105205315015030.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107115615015035.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106596215010021.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105200815010009.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107111315010162.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106144915010013.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105686115010047.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105682415015027.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105684015010002.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106143715015042.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106594415010014.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106596115015044.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107115715015111.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106146115010027.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581715015014.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105683015010034.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107580015015044.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108986315015009.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106595115015022.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107585815010002.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105684615010018.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107114115015050.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107583615015018.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106593315010015.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108980815015061.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108983615010002.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107113015010257.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107112815015061.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107584115015059.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108045315015000.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107114515015066.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105685515010028.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105681115015002.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107111315010234.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108984915010028.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106591315010014.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108041315015006.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107110515010073.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108041215015061.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106145515010001.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106590015010001.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108981615010004.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106591315015005.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105681115015020.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107115615015025.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107110915010030.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107114315015062.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107111515015118.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107114415015077.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106144115015013.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105204015015015.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108040715015058.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105204015010013.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106596015015010.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106144415010011.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107113815015054.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108981515010009.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581415010429.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108045615010021.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108043915010001.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105204215010015.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645097516215010003.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107116115010033.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107580515010089.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106146115010036.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108040315015017.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581415010166.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581215010090.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107114315015077.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105682015010004.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108041315010004.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106595615010041.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106142615010025.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106142715015045.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108982415010008.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107586315010029.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105200715010003.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108044115010015.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105685215010035.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107111415015232.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581715010011.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106144515015048.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106143015015028.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107583315010006.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107114415010055.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107112415010010.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106
032.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105683715010027.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108980515010001.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106594315015016.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107114715015270.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107583415010013.avro',
# ...
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106141615015056.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645097023315010001.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105683315015032.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105200115010002.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105684715010013.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108040915015027.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106142815010020.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108980315015093.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106142415010011.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106146315015008.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107583015010351.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108044815015050.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581215010161.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108983415015026.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107111515010136.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108040215015015.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106145615010021.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106142615010010.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106143415010006.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105200715015029.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107580615015000.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107111315015167.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108040215010002.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105684515015012.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108043615015023.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105681315015018.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108045015010022.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106596315010032.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107114615015019.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108043615010009.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106143015010023.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106144015010011.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107110215010007.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107112815015033.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581215010058.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107114715015002.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108044715010013.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581515015061.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107112115015007.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581515010503.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105683115010014.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106596215010025.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107113815015044.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105685015010010.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581515010037.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107115615010003.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107115515015011.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108986215010003.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107583715010005.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105682815010049.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106590915015026.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108040515010011.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107582315015040.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107111315010389.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105684215010025.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106592815010010.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107585815010022.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107584015015033.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106140215010016.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108982315010010.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105683015010014.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108040715015007.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108042215015046.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107110815010012.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106140115015058.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106595515015018.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107111615015022.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106596315015033.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108045415010004.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107580015010009.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108040315015043.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106141215010029.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105684115010002.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107114515015161.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107113515010015.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108984315010031.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106146015010039.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106143015010026.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581515015063.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108040315010005.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645097024715015005.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105206315010004.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106142515010013.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107115915010175.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107582915010043.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108044115015049.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107583015010252.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108981515010022.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108045515010010.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108041615010018.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106593915015020.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106141315015025.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105200415015004.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106591315015020.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107111415015095.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106146115015003.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107586015015050.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108041815015026.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581515010168.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107583015015002.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581515010465.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581215015052.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107112015015000.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107110015015054.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107583015010310.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107585415010061.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107116215015089.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107583015015037.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106146215010015.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106145315010022.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107112315010108.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106592115010000.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105683515015052.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108043815010013.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581615010007.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107111315010401.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105205815010002.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106145215010002.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105200515015010.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107112815010032.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106141615010006.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106143815015024.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581115015025.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581415010340.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108044515010005.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107114115015054.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105202315010004.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107116115010019.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105200015015021.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106593715010016.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581515010417.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105683915015009.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581715015030.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106595715015006.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581415010032.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108981515010023.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106142215015018.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105204515015026.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105680515010016.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581415010410.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106141415010021.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105203415010015.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105683715010010.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108041515010008.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105680715015000.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106141915015015.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108044315010059.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107114815010000.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105680715015041.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106141315015039.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106146015015013.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107114015010008.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107112815010003.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107582615010020.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107586215010009.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105680915010071.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581415015300.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107114715015214.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106144815010008.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106590815015015.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108980615015051.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107111715015013.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108044815015013.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107111415015201.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107116115010014.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107111315015040.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107110415015005.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105206115010013.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107111315015074.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581215010145.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107110615010056.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106144715010017.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108045015015073.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107115415010065.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106594515015018.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105205215015022.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107585715010009.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108042615010007.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645105686315015024.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108045615015010.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108043115010038.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107583015010399.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107584515010019.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108045315010003.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108041215015058.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581415015008.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107580415010002.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107111315010028.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107110515010035.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107582615015019.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106144915010021.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107581415010275.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106596115010026.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108041515010010.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645108041715015058.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645107115615015126.avro',
#  '../../ztf-avro-alert/data/public/ztf_public_20181008/645106143315010027.avro',
#  ...]

# %%
print('{} has {} avro files'.format(DATA_DIR, len(list(find_files(DATA_DIR)))))
# Out:
# ../../ztf-avro-alert/data has 38498 avro files

# %% [markdown]
# Let's grab the first file and look at it

# %%
#files_gen = find_files(DATA_DIR)
fname = next(files_gen)

# %%
fname = next(files_gen)

# %%
fname
# Out:
# '../../ztf-avro-alert/data/public/ztf_public_20181008/645105682815010009.avro'

# %% [markdown]
# Let's use the python `avro` library to see what's in the file.

# %%
# %%time
with open(fname,'rb') as f:
    freader = DataFileReader(f,DatumReader())
    for packet in freader:
        print(packet.keys())
# Out:
# dict_keys(['candidate', 'prv_candidates', 'candid', 'objectId', 'schemavsn', 'cutoutDifference', 'publisher', 'cutoutTemplate', 'cutoutScience'])
# CPU times: user 45.2 ms, sys: 526 µs, total: 45.7 ms
# Wall time: 70 ms

# %% [markdown]
# Now let's compare the call syntax of the faster `fastavro` package:

# %%
# %%time 
with open(fname,'rb') as f:
    freader = fastavro.reader(f)
    schema = freader.schema

    for packet in freader:
        print(packet.keys())
# Out:
# dict_keys(['candidate', 'prv_candidates', 'candid', 'objectId', 'schemavsn', 'cutoutDifference', 'publisher', 'cutoutTemplate', 'cutoutScience'])
# CPU times: user 13.4 ms, sys: 94 µs, total: 13.5 ms
# Wall time: 11.7 ms

# %% [markdown]
# Basically the same, and the latter is faster.  Here's the schema that was stored in the packet:

# %%
schema['fields']
# Out:
# [{'doc': 'schema version used', 'name': 'schemavsn', 'type': 'string'},
#  {'doc': 'origin of alert packet', 'name': 'publisher', 'type': 'string'},
#  {'doc': 'object identifier or name', 'name': 'objectId', 'type': 'string'},
#  {'name': 'candid', 'type': 'long'},
#  {'name': 'candidate',
#   'type': {'doc': 'avro alert schema',
#    'fields': [{'doc': 'Observation Julian date at start of exposure [days]',
#      'name': 'jd',
#      'type': 'double'},
#     {'doc': 'Filter ID (1=g; 2=R; 3=i)', 'name': 'fid', 'type': 'int'},
#     {'doc': 'Processing ID for science image to facilitate archive retrieval',
#      'name': 'pid',
#      'type': 'long'},
#     {'default': None,
#      'doc': 'Expected 5-sigma mag limit in difference image based on global noise estimate [mag]',
#      'name': 'diffmaglim',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'filename of positive (sci minus ref) difference image',
#      'name': 'pdiffimfilename',
#      'type': ['string', 'null']},
#     {'default': None,
#      'doc': 'Principal investigator attached to program ID',
#      'name': 'programpi',
#      'type': ['string', 'null']},
#     {'doc': 'Program ID: encodes either public, collab, or caltech mode',
#      'name': 'programid',
#      'type': 'int'},
#     {'doc': 'Candidate ID from operations DB',
#      'name': 'candid',
#      'type': 'long'},
#     {'doc': 't or 1 => candidate is from positive (sci minus ref) subtraction; f or 0 => candidate is from negative (ref minus sci) subtraction',
#      'name': 'isdiffpos',
#      'type': 'string'},
#     {'default': None,
#      'doc': 'Internal pipeline table extraction ID',
#      'name': 'tblid',
#      'type': ['long', 'null']},
#     {'default': None,
#      'doc': 'Night ID',
#      'name': 'nid',
#      'type': ['int', 'null']},
#     {'default': None,
#      'doc': 'Readout channel ID [00 .. 63]',
#      'name': 'rcid',
#      'type': ['int', 'null']},
#     {'default': None,
#      'doc': 'ZTF field ID',
#      'name': 'field',
#      'type': ['int', 'null']},
#     {'default': None,
#      'doc': 'x-image position of candidate [pixels]',
#      'name': 'xpos',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'y-image position of candidate [pixels]',
#      'name': 'ypos',
#      'type': ['float', 'null']},
#     {'doc': 'Right Ascension of candidate; J2000 [deg]',
#      'name': 'ra',
#      'type': 'double'},
#     {'doc': 'Declination of candidate; J2000 [deg]',
#      'name': 'dec',
#      'type': 'double'},
#     {'doc': 'Magnitude from PSF-fit photometry [mag]',
#      'name': 'magpsf',
#      'type': 'float'},
#     {'doc': '1-sigma uncertainty in magpsf [mag]',
#      'name': 'sigmapsf',
#      'type': 'float'},
#     {'default': None,
#      'doc': 'Reduced chi-square for PSF-fit',
#      'name': 'chipsf',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Aperture mag using 14 pixel diameter aperture [mag]',
#      'name': 'magap',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': '1-sigma uncertainty in magap [mag]',
#      'name': 'sigmagap',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'distance to nearest source in reference image PSF-catalog [pixels]',
#      'name': 'distnr',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'magnitude of nearest source in reference image PSF-catalog [mag]',
#      'name': 'magnr',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': '1-sigma uncertainty in magnr [mag]',
#      'name': 'sigmagnr',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'DAOPhot chi parameter of nearest source in reference image PSF-catalog',
#      'name': 'chinr',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'DAOPhot sharp parameter of nearest source in reference image PSF-catalog',
#      'name': 'sharpnr',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Local sky background estimate [DN]',
#      'name': 'sky',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Difference: magap - magpsf [mag]',
#      'name': 'magdiff',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Full Width Half Max assuming a Gaussian core, from SExtractor [pixels]',
#      'name': 'fwhm',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Star/Galaxy classification score from SExtractor',
#      'name': 'classtar',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Distance to nearest edge in image [pixels]',
#      'name': 'mindtoedge',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Difference: diffmaglim - magap [mag]',
#      'name': 'magfromlim',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Ratio: difffwhm / fwhm',
#      'name': 'seeratio',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Windowed profile RMS afloat major axis from SExtractor [pixels]',
#      'name': 'aimage',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Windowed profile RMS afloat minor axis from SExtractor [pixels]',
#      'name': 'bimage',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Ratio: aimage / fwhm',
#      'name': 'aimagerat',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Ratio: bimage / fwhm',
#      'name': 'bimagerat',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Ratio: aimage / bimage',
#      'name': 'elong',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'number of negative pixels in a 5 x 5 pixel stamp',
#      'name': 'nneg',
#      'type': ['int', 'null']},
#     {'default': None,
#      'doc': 'number of prior-tagged bad pixels in a 5 x 5 pixel stamp',
#      'name': 'nbad',
#      'type': ['int', 'null']},
#     {'default': None,
#      'doc': 'RealBogus quality score; range is 0 to 1 where closer to 1 is more reliable',
#      'name': 'rb',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'distance to nearest known solar system object if exists within 30 arcsec [arcsec]',
#      'name': 'ssdistnr',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'magnitude of nearest known solar system object if exists within 30 arcsec (usually V-band from MPC archive) [mag]',
#      'name': 'ssmagnr',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'name of nearest known solar system object if exists within 30 arcsec (from MPC archive)',
#      'name': 'ssnamenr',
#      'type': ['string', 'null']},
#     {'default': None,
#      'doc': 'Ratio: sum(pixels) / sum(|pixels|) in a 5 x 5 pixel stamp where stamp is first median-filtered to mitigate outliers',
#      'name': 'sumrat',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Aperture mag using 18 pixel diameter aperture [mag]',
#      'name': 'magapbig',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': '1-sigma uncertainty in magapbig [mag]',
#      'name': 'sigmagapbig',
#      'type': ['float', 'null']},
#     {'doc': 'Right Ascension of nearest source in reference image PSF-catalog; J2000 [deg]',
#      'name': 'ranr',
#      'type': 'double'},
#     {'doc': 'Declination of nearest source in reference image PSF-catalog; J2000 [deg]',
#      'name': 'decnr',
#      'type': 'double'},
#     {'default': None,
#      'doc': 'g-band PSF-fit magnitude of closest source from PS1 catalog; if exists within 30 arcsec [mag]',
#      'name': 'sgmag1',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'r-band PSF-fit magnitude of closest source from PS1 catalog; if exists within 30 arcsec [mag]',
#      'name': 'srmag1',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'i-band PSF-fit magnitude of closest source from PS1 catalog; if exists within 30 arcsec [mag]',
#      'name': 'simag1',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'z-band PSF-fit magnitude of closest source from PS1 catalog; if exists within 30 arcsec [mag]',
#      'name': 'szmag1',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Star/Galaxy score of closest source from PS1 catalog; if exists within 30 arcsec: 0 <= sgscore <= 1 where closer to 1 implies higher likelihood of being a star',
#      'name': 'sgscore1',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Distance to closest source from PS1 catalog; if exists within 30 arcsec [arcsec]',
#      'name': 'distpsnr1',
#      'type': ['float', 'null']},
#     {'doc': 'Number of spatially-coincident detections falling within 1.5 arcsec going back to beginning of survey; only detections that fell on the same field and readout-channel ID where the input candidate was observed are counted',
#      'name': 'ndethist',
#      'type': 'int'},
#     {'doc': 'Number of times input candidate position fell on any field and readout-channel going back to beginning of survey',
#      'name': 'ncovhist',
#      'type': 'int'},
#     {'default': None,
#      'doc': 'Earliest Julian date of epoch corresponding to ndethist [days]',
#      'name': 'jdstarthist',
#      'type': ['double', 'null']},
#     {'default': None,
#      'doc': 'Latest Julian date of epoch corresponding to ndethist [days]',
#      'name': 'jdendhist',
#      'type': ['double', 'null']},
#     {'default': None,
#      'doc': 'Peak-pixel signal-to-noise ratio in point source matched-filtered detection image',
#      'name': 'scorr',
#      'type': ['double', 'null']},
#     {'default': 0,
#      'doc': '1 => candidate is from a Target-of-Opportunity (ToO) exposure; 0 => candidate is from a non-ToO exposure',
#      'name': 'tooflag',
#      'type': ['int', 'null']},
#     {'default': None,
#      'doc': 'Object ID of closest source from PS1 catalog; if exists within 30 arcsec',
#      'name': 'objectidps1',
#      'type': ['long', 'null']},
#     {'default': None,
#      'doc': 'Object ID of second closest source from PS1 catalog; if exists within 30 arcsec',
#      'name': 'objectidps2',
#      'type': ['long', 'null']},
#     {'default': None,
#      'doc': 'g-band PSF-fit magnitude of second closest source from PS1 catalog; if exists within 30 arcsec [mag]',
#      'name': 'sgmag2',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'r-band PSF-fit magnitude of second closest source from PS1 catalog; if exists within 30 arcsec [mag]',
#      'name': 'srmag2',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'i-band PSF-fit magnitude of second closest source from PS1 catalog; if exists within 30 arcsec [mag]',
#      'name': 'simag2',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'z-band PSF-fit magnitude of second closest source from PS1 catalog; if exists within 30 arcsec [mag]',
#      'name': 'szmag2',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Star/Galaxy score of second closest source from PS1 catalog; if exists within 30 arcsec: 0 <= sgscore <= 1 where closer to 1 implies higher likelihood of being a star',
#      'name': 'sgscore2',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Distance to second closest source from PS1 catalog; if exists within 30 arcsec [arcsec]',
#      'name': 'distpsnr2',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Object ID of third closest source from PS1 catalog; if exists within 30 arcsec',
#      'name': 'objectidps3',
#      'type': ['long', 'null']},
#     {'default': None,
#      'doc': 'g-band PSF-fit magnitude of third closest source from PS1 catalog; if exists within 30 arcsec [mag]',
#      'name': 'sgmag3',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'r-band PSF-fit magnitude of third closest source from PS1 catalog; if exists within 30 arcsec [mag]',
#      'name': 'srmag3',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'i-band PSF-fit magnitude of third closest source from PS1 catalog; if exists within 30 arcsec [mag]',
#      'name': 'simag3',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'z-band PSF-fit magnitude of third closest source from PS1 catalog; if exists within 30 arcsec [mag]',
#      'name': 'szmag3',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Star/Galaxy score of third closest source from PS1 catalog; if exists within 30 arcsec: 0 <= sgscore <= 1 where closer to 1 implies higher likelihood of being a star',
#      'name': 'sgscore3',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Distance to third closest source from PS1 catalog; if exists within 30 arcsec [arcsec]',
#      'name': 'distpsnr3',
#      'type': ['float', 'null']},
#     {'doc': 'Number of source matches from PS1 catalog falling within 30 arcsec',
#      'name': 'nmtchps',
#      'type': 'int'},
#     {'doc': 'Processing ID for reference image to facilitate archive retrieval',
#      'name': 'rfid',
#      'type': 'long'},
#     {'doc': 'Observation Julian date of earliest exposure used to generate reference image [days]',
#      'name': 'jdstartref',
#      'type': 'double'},
#     {'doc': 'Observation Julian date of latest exposure used to generate reference image [days]',
#      'name': 'jdendref',
#      'type': 'double'},
#     {'doc': 'Number of frames (epochal images) used to generate reference image',
#      'name': 'nframesref',
#      'type': 'int'},
#     {'doc': 'version of RealBogus model/classifier used to assign rb quality score',
#      'name': 'rbversion',
#      'type': 'string'},
#     {'default': None,
#      'doc': 'Ratio: D/stddev(D) on event position where D = difference image',
#      'name': 'dsnrms',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Ratio: S/stddev(S) on event position where S = image of convolution: D (x) PSF(D)',
#      'name': 'ssnrms',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Difference of statistics: dsnrms - ssnrms',
#      'name': 'dsdiff',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Magnitude zero point for photometry estimates [mag]',
#      'name': 'magzpsci',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Magnitude zero point uncertainty (in magzpsci) [mag]',
#      'name': 'magzpsciunc',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'RMS (deviation from average) in all differences between instrumental photometry and matched photometric calibrators from science image processing [mag]',
#      'name': 'magzpscirms',
#      'type': ['float', 'null']},
#     {'doc': 'Number of PS1 photometric calibrators used to calibrate science image from science image processing',
#      'name': 'nmatches',
#      'type': 'int'},
#     {'default': None,
#      'doc': 'Color coefficient from linear fit from photometric calibration of science image',
#      'name': 'clrcoeff',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Color coefficient uncertainty from linear fit (corresponding to clrcoeff)',
#      'name': 'clrcounc',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Covariance in magzpsci and clrcoeff from science image processing [mag^2]',
#      'name': 'zpclrcov',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Magnitude zero point from median of all differences between instrumental photometry and matched photometric calibrators from science image processing [mag]',
#      'name': 'zpmed',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Median color of all PS1 photometric calibrators used from science image processing [mag]: for filter (fid) = 1, 2, 3, PS1 color used = g-r, g-r, r-i respectively',
#      'name': 'clrmed',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'RMS color (deviation from average) of all PS1 photometric calibrators used from science image processing [mag]',
#      'name': 'clrrms',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Distance to closest source from Gaia DR1 catalog irrespective of magnitude; if exists within 90 arcsec [arcsec]',
#      'name': 'neargaia',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Distance to closest source from Gaia DR1 catalog brighter than magnitude 14; if exists within 90 arcsec [arcsec]',
#      'name': 'neargaiabright',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Gaia (G-band) magnitude of closest source from Gaia DR1 catalog irrespective of magnitude; if exists within 90 arcsec [mag]',
#      'name': 'maggaia',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Gaia (G-band) magnitude of closest source from Gaia DR1 catalog brighter than magnitude 14; if exists within 90 arcsec [mag]',
#      'name': 'maggaiabright',
#      'type': ['float', 'null']},
#     {'default': None,
#      'doc': 'Integration time of camera exposure [sec]',
#      'name': 'exptime',
#      'type': ['float', 'null']}],
#    'name': 'candidate',
#    'namespace': 'ztf.alert',
#    'type': 'record',
#    'version': '3.1'}},
#  {'default': None,
#   'name': 'prv_candidates',
#   'type': [{'items': {'doc': 'avro alert schema',
#      'fields': [{'doc': 'Observation Julian date at start of exposure [days]',
#        'name': 'jd',
#        'type': 'double'},
#       {'doc': 'Filter ID (1=g; 2=R; 3=i)', 'name': 'fid', 'type': 'int'},
#       {'doc': 'Processing ID for image', 'name': 'pid', 'type': 'long'},
#       {'default': None,
#        'doc': 'Expected 5-sigma mag limit in difference image based on global noise estimate [mag]',
#        'name': 'diffmaglim',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': 'filename of positive (sci minus ref) difference image',
#        'name': 'pdiffimfilename',
#        'type': ['string', 'null']},
#       {'default': None,
#        'doc': 'Principal investigator attached to program ID',
#        'name': 'programpi',
#        'type': ['string', 'null']},
#       {'doc': 'Program ID: encodes either public, collab, or caltech mode',
#        'name': 'programid',
#        'type': 'int'},
#       {'doc': 'Candidate ID from operations DB',
#        'name': 'candid',
#        'type': ['long', 'null']},
#       {'doc': 't or 1 => candidate is from positive (sci minus ref) subtraction; f or 0 => candidate is from negative (ref minus sci) subtraction',
#        'name': 'isdiffpos',
#        'type': ['string', 'null']},
#       {'default': None,
#        'doc': 'Internal pipeline table extraction ID',
#        'name': 'tblid',
#        'type': ['long', 'null']},
#       {'default': None,
#        'doc': 'Night ID',
#        'name': 'nid',
#        'type': ['int', 'null']},
#       {'default': None,
#        'doc': 'Readout channel ID [00 .. 63]',
#        'name': 'rcid',
#        'type': ['int', 'null']},
#       {'default': None,
#        'doc': 'ZTF field ID',
#        'name': 'field',
#        'type': ['int', 'null']},
#       {'default': None,
#        'doc': 'x-image position of candidate [pixels]',
#        'name': 'xpos',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': 'y-image position of candidate [pixels]',
#        'name': 'ypos',
#        'type': ['float', 'null']},
#       {'doc': 'Right Ascension of candidate; J2000 [deg]',
#        'name': 'ra',
#        'type': ['double', 'null']},
#       {'doc': 'Declination of candidate; J2000 [deg]',
#        'name': 'dec',
#        'type': ['double', 'null']},
#       {'doc': 'Magnitude from PSF-fit photometry [mag]',
#        'name': 'magpsf',
#        'type': ['float', 'null']},
#       {'doc': '1-sigma uncertainty in magpsf [mag]',
#        'name': 'sigmapsf',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': 'Reduced chi-square for PSF-fit',
#        'name': 'chipsf',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': 'Aperture mag using 14 pixel diameter aperture [mag]',
#        'name': 'magap',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': '1-sigma uncertainty in magap [mag]',
#        'name': 'sigmagap',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': 'distance to nearest source in reference image PSF-catalog [pixels]',
#        'name': 'distnr',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': 'magnitude of nearest source in reference image PSF-catalog [mag]',
#        'name': 'magnr',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': '1-sigma uncertainty in magnr [mag]',
#        'name': 'sigmagnr',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': 'DAOPhot chi parameter of nearest source in reference image PSF-catalog',
#        'name': 'chinr',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': 'DAOPhot sharp parameter of nearest source in reference image PSF-catalog',
#        'name': 'sharpnr',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': 'Local sky background estimate [DN]',
#        'name': 'sky',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': 'Difference: magap - magpsf [mag]',
#        'name': 'magdiff',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': 'Full Width Half Max assuming a Gaussian core, from SExtractor [pixels]',
#        'name': 'fwhm',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': 'Star/Galaxy classification score from SExtractor',
#        'name': 'classtar',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': 'Distance to nearest edge in image [pixels]',
#        'name': 'mindtoedge',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': 'Difference: diffmaglim - magap [mag]',
#        'name': 'magfromlim',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': 'Ratio: difffwhm / fwhm',
#        'name': 'seeratio',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': 'Windowed profile RMS afloat major axis from SExtractor [pixels]',
#        'name': 'aimage',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': 'Windowed profile RMS afloat minor axis from SExtractor [pixels]',
#        'name': 'bimage',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': 'Ratio: aimage / fwhm',
#        'name': 'aimagerat',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': 'Ratio: bimage / fwhm',
#        'name': 'bimagerat',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': 'Ratio: aimage / bimage',
#        'name': 'elong',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': 'number of negative pixels in a 5 x 5 pixel stamp',
#        'name': 'nneg',
#        'type': ['int', 'null']},
#       {'default': None,
#        'doc': 'number of prior-tagged bad pixels in a 5 x 5 pixel stamp',
#        'name': 'nbad',
#        'type': ['int', 'null']},
#       {'default': None,
#        'doc': 'RealBogus quality score; range is 0 to 1 where closer to 1 is more reliable',
#        'name': 'rb',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': 'distance to nearest known solar system object if exists within 30 arcsec [arcsec]',
#        'name': 'ssdistnr',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': 'magnitude of nearest known solar system object if exists within 30 arcsec (usually V-band from MPC archive) [mag]',
#        'name': 'ssmagnr',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': 'name of nearest known solar system object if exists within 30 arcsec (from MPC archive)',
#        'name': 'ssnamenr',
#        'type': ['string', 'null']},
#       {'default': None,
#        'doc': 'Ratio: sum(pixels) / sum(|pixels|) in a 5 x 5 pixel stamp where stamp is first median-filtered to mitigate outliers',
#        'name': 'sumrat',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': 'Aperture mag using 18 pixel diameter aperture [mag]',
#        'name': 'magapbig',
#        'type': ['float', 'null']},
#       {'default': None,
#        'doc': '1-sigma uncertainty in magapbig [mag]',
#        'name': 'sigmagapbig',
#        'type': ['float', 'null']},
#       {'doc': 'Right Ascension of nearest source in reference image PSF-catalog; J2000 [deg]',
#        'name': 'ranr',
#        'type': ['double', 'null']},
#       {'doc': 'Declination of nearest source in reference image PSF-catalog; J2000 [deg]',
#        'name': 'decnr',
#        'type': ['double', 'null']},
#       {'default': None,
#        'doc': 'Peak-pixel signal-to-noise ratio in point source matched-filtered detection image',
#        'name': 'scorr',
#        'type': ['double', 'null']},
#       {'doc': 'version of RealBogus model/classifier used to assign rb quality score',
#        'name': 'rbversion',
#        'type': 'string'}],
#      'name': 'prv_candidate',
#      'namespace': 'ztf.alert',
#      'type': 'record',
#      'version': '3.1'},
#     'type': 'array'},
#    'null']},
#  {'default': None,
#   'name': 'cutoutScience',
#   'type': [{'doc': 'avro alert schema',
#     'fields': [{'name': 'fileName', 'type': 'string'},
#      {'doc': 'fits.gz', 'name': 'stampData', 'type': 'bytes'}],
#     'name': 'cutout',
#     'namespace': 'ztf.alert',
#     'type': 'record',
#     'version': '3.1'},
#    'null']},
#  {'default': None,
#   'name': 'cutoutTemplate',
#   'type': ['ztf.alert.cutout', 'null']},
#  {'default': None,
#   'name': 'cutoutDifference',
#   'type': ['ztf.alert.cutout', 'null']}]

# %% [markdown]
# Once we have the packet in python data structures our downstream processing should be independent of how we got the packet (from files or from a Kafka stream).

# %% [markdown]
# ### Playing with packet contents

# %% [markdown]
# Once these are in memory they are just a python dictionary, so the top-level attributes are easy to access.

# %%
type(packet)
# Out:
# dict

# %%
packet['candidate']
# Out:
# {'aimage': 0.7799999713897705,
#  'aimagerat': 0.5025056600570679,
#  'bimage': 0.6790000200271606,
#  'bimagerat': 0.43743765354156494,
#  'candid': 645105682815010009,
#  'chinr': 0.24799999594688416,
#  'chipsf': 1.3871427774429321,
#  'classtar': 0.8989999890327454,
#  'clrcoeff': -0.07269900292158127,
#  'clrcounc': 7.665000339329708e-06,
#  'clrmed': 0.7110000252723694,
#  'clrrms': 0.17551900446414948,
#  'dec': 11.6237398,
#  'decnr': 11.6237498,
#  'diffmaglim': 20.11449432373047,
#  'distnr': 0.0811409205198288,
#  'distpsnr1': 0.12094170600175858,
#  'distpsnr2': 2.3398547172546387,
#  'distpsnr3': 7.01094388961792,
#  'dsdiff': -8.378232955932617,
#  'dsnrms': 10.600648880004883,
#  'elong': 1.1487481594085693,
#  'exptime': 30.0,
#  'fid': 1,
#  'field': 541,
#  'fwhm': 1.5522211790084839,
#  'isdiffpos': 'f',
#  'jd': 2458399.6056829,
#  'jdendhist': 2458399.6056829,
#  'jdendref': 2458344.839711,
#  'jdstarthist': 2458348.8516435,
#  'jdstartref': 2458230.99787,
#  'magap': 19.835399627685547,
#  'magapbig': 19.84280014038086,
#  'magdiff': 0.5171589851379395,
#  'magfromlim': 0.2790949046611786,
#  'maggaia': 20.320072174072266,
#  'maggaiabright': 12.9105806350708,
#  'magnr': 16.8439998626709,
#  'magpsf': 19.318241119384766,
#  'magzpsci': 26.206241607666016,
#  'magzpscirms': 0.024477999657392502,
#  'magzpsciunc': 4.54380005976418e-06,
#  'mindtoedge': 135.8278045654297,
#  'nbad': 0,
#  'ncovhist': 139,
#  'ndethist': 8,
#  'neargaia': 6.975552082061768,
#  'neargaiabright': 60.636661529541016,
#  'nframesref': 15,
#  'nid': 645,
#  'nmatches': 1848,
#  'nmtchps': 61,
#  'nneg': 2,
#  'objectidps1': 121942964741828956,
#  'objectidps2': 121942964738369270,
#  'objectidps3': 121952964735091237,
#  'pdiffimfilename': 'ztf_20181008105660_000541_zg_c08_o_q1_scimrefdiffimg.fits',
#  'pid': 645105682815,
#  'programid': 1,
#  'programpi': 'Kulkarni',
#  'ra': 296.4742044,
#  'ranr': 296.4742237,
#  'rb': 0.7200000286102295,
#  'rbversion': 't8_f5_c3',
#  'rcid': 28,
#  'rfid': 541120128,
#  'scorr': 5.33766603469849,
#  'seeratio': 2.0,
#  'sgmag1': 16.436800003051758,
#  'sgmag2': -999.0,
#  'sgmag3': 21.164100646972656,
#  'sgscore1': 0.7768539786338806,
#  'sgscore2': 0.5,
#  'sgscore3': 0.62049400806427,
#  'sharpnr': 0.014999999664723873,
#  'sigmagap': 0.25619998574256897,
#  'sigmagapbig': 0.32409998774528503,
#  'sigmagnr': 0.012000000104308128,
#  'sigmapsf': 0.15439929068088531,
#  'simag1': 12.142000198364258,
#  'simag2': -999.0,
#  'simag3': -999.0,
#  'sky': 0.5337489247322083,
#  'srmag1': 14.668999671936035,
#  'srmag2': -999.0,
#  'srmag3': 20.442100524902344,
#  'ssdistnr': -999.0,
#  'ssmagnr': -999.0,
#  'ssnamenr': 'null',
#  'ssnrms': 18.9788818359375,
#  'sumrat': 1.0,
#  'szmag1': 10.960000038146973,
#  'szmag2': 15.73740005493164,
#  'szmag3': -999.0,
#  'tblid': 9,
#  'tooflag': 0,
#  'xpos': 1639.8709716796875,
#  'ypos': 135.8278045654297,
#  'zpclrcov': -5.750000127591193e-06,
#  'zpmed': 26.152999877929688}

# %%
print('JD: {} Filter: {} Mag: {:.2f}+/-{:.2f}'.format(
    packet['candidate']['jd'],packet['candidate']['fid'],
    packet['candidate']['magpsf'],packet['candidate']['sigmapsf']))
# Out:
# JD: 2458399.6056829 Filter: 1 Mag: 19.32+/-0.15

# %%
len(packet['prv_candidates'])
# Out:
# 7

# %% [markdown]
# **NOTE ESPECIALLY**: the magnitudes here do not include the magnitude of the underlying reference source (if present), so if this is a variable star further adjustment is needed.  Example to come...

# %% [markdown]
# Record access like this is a little verbose; let's wrap things up in a dataframe for ease of access (and faster loading).

# %% [markdown]
# Now let's extract the lightcurves.  The alert packet formats are nested, so the historical detections (if present) have the same structure as the candidate triggering the alert (minus a couple fields).

# %%
def make_dataframe(packet):
    df = pd.DataFrame(packet['candidate'], index=[0])
    df_prv = pd.DataFrame(packet['prv_candidates'])
    return pd.concat([df,df_prv], ignore_index=True,sort=False)

# %%
dflc = make_dataframe(packet)
dflc
# Out:
#    aimage  aimagerat  bimage  bimagerat        candid  chinr    chipsf  \
# 0   0.780   0.502506   0.679   0.437438  6.451057e+17  0.248  1.387143
# 1     NaN        NaN     NaN        NaN           NaN    NaN       NaN
# 2   0.594   0.495009   0.510   0.425007  6.152308e+17  0.248  1.981360
# 3     NaN        NaN     NaN        NaN           NaN    NaN       NaN
# 4   0.616   0.268996   0.547   0.238865  6.182288e+17  0.248  7.364290
# 5   0.689   0.193539   0.575   0.161517  6.212283e+17  0.248  5.704380
# 6   0.639   0.276623   0.583   0.252381  6.241913e+17  0.248  4.443470
# 7     NaN        NaN     NaN        NaN           NaN    NaN       NaN
#
#    classtar  clrcoeff  clrcounc   ...      sumrat  szmag1   szmag2  szmag3  \
# 0     0.899 -0.072699  0.000008   ...    1.000000   10.96  15.7374  -999.0
# 1       NaN       NaN       NaN   ...         NaN     NaN      NaN     NaN
# 2     0.994       NaN       NaN   ...    0.985135     NaN      NaN     NaN
# 3       NaN       NaN       NaN   ...         NaN     NaN      NaN     NaN
# 4     0.969       NaN       NaN   ...    0.974669     NaN      NaN     NaN
# 5     1.000       NaN       NaN   ...    0.966410     NaN      NaN     NaN
# 6     0.997       NaN       NaN   ...    1.000000     NaN      NaN     NaN
# 7       NaN       NaN       NaN   ...         NaN     NaN      NaN     NaN
#
#    tblid  tooflag         xpos        ypos  zpclrcov   zpmed
# 0    9.0      0.0  1639.870972  135.827805 -0.000006  26.153
# 1    NaN      NaN          NaN         NaN       NaN     NaN
# 2    0.0      NaN  1639.880005   38.973099       NaN     NaN
# 3    NaN      NaN          NaN         NaN       NaN     NaN
# 4    2.0      NaN  1640.270020   59.679699       NaN     NaN
# 5    0.0      NaN  1639.579956   33.739201       NaN     NaN
# 6    0.0      NaN  1635.219971   41.711201       NaN     NaN
# 7    NaN      NaN          NaN         NaN       NaN     NaN
#
# [8 rows x 101 columns]

# %%
dflc.columns
# Out:
# Index(['aimage', 'aimagerat', 'bimage', 'bimagerat', 'candid', 'chinr',
#        'chipsf', 'classtar', 'clrcoeff', 'clrcounc',
#        ...
#        'sumrat', 'szmag1', 'szmag2', 'szmag3', 'tblid', 'tooflag', 'xpos',
#        'ypos', 'zpclrcov', 'zpmed'],
#       dtype='object', length=101)

# %% [markdown]
# We see that some of the historical detections are upper limits, signified by the NaNs.  Note that the most recent candidate has a few fields that are not present for the `prv_candidates`.
#
# Let's plot it!

# %%
def plot_lightcurve(dflc, days_ago=True):
    
    filter_color = {1:'green', 2:'red', 3:'pink'}
    if days_ago:
        now = Time.now().jd
        t = dflc.jd - now
        xlabel = 'Days Ago'
    else:
        t = dflc.jd
        xlabel = 'Time (JD)'
    
    plt.figure()
    for fid, color in filter_color.items():
        # plot detections in this filter:
        w = (dflc.fid == fid) & ~dflc.magpsf.isnull()
        if np.sum(w):
            plt.errorbar(t[w],dflc.loc[w,'magpsf'], dflc.loc[w,'sigmapsf'],fmt='.',color=color)
        wnodet = (dflc.fid == fid) & dflc.magpsf.isnull()
        if np.sum(wnodet):
            plt.scatter(t[wnodet],dflc.loc[wnodet,'diffmaglim'], marker='v',color=color,alpha=0.25)
0\x0f\xbb\x882\xfe:\xdeT\x9b\x88}+;\x94(\xef~\xfa\x12B\xfe\xb1\x948\xfe\x85@\x97>(S\x9b`\x1f\xd1\x03\xef\x0fN\xa26\xd4%\xf0x\x04z\xa3\xce\xf86t\xc4Ui%\x9e_/a\xad\xb9\x8fc\xcf\x01\\\xa1Wp\xc3B\x9dy\x035`\xc7\xd3f:\xbe\x1e\th\x17\xaf\xe0OlF\\\xadM\x04\xf2\x8eC\xeb/s38\x96\xd0_\xf7\xe4\xacN\xa1\xf6\x1dN\xf8\xc8\x1b\xac}c0;~\xc0\xd7>\n\xcfv\x05w\xa2\xec\xc5\x8ba\x92W\xcd\xd1v\xde\xc0l\x9f\x1f\xf5\xd2y\x9c\xfd;`\xf9\xf7\xe2\xdc\xbc\x05\xbd\\\x11\x8c\xdc\x85d\x7f\xcf\xa1\xbe\xfa\x82\xa3\xd5DB1y\xf0e\x9d$_\xdb\x18\xe7\xd9|\xe8\xfd\xeb\xa3\xde\xd70nT\xc2\xbfr(\xde\xc3?\x13\xadlC;\x96\x88nO\x86\xafAuL\xd91\xb3\x91\x0fobn\xcc\x87\xd3Q\x8ag\xa3\xc4\x8c28\x17\xf4\xc2\xd3p%F\xb7\n\xd8\xf64\xc4\xd9m\x0e\xde\x95\xdfP\xfb\xcb\xb9&n\xc4:7O\x9e3\x1df\xb2\x93(\rF\x11\xd3s\x17\xd6\xad,\xe8K-\x8c\xa8[\xd8>\x9e\x92y:\x8a\'\xfdP\x94\x83m\xd1?\xe4"\xb0 ...

# %%
stamp = packet['cutoutScience']['stampData']

# %%
type(stamp)
# Out:
# bytes

# %%
def plot_cutout(stamp, fig=None, subplot=None, **kwargs):
    with gzip.open(io.BytesIO(stamp), 'rb') as f:
        with fits.open(io.BytesIO(f.read())) as hdul:
            if fig is None:
                fig = plt.figure(figsize=(4,4))
            if subplot is None:
                subplot = (1,1,1)
            ffig = aplpy.FITSFigure(hdul[0],figure=fig, subplot=subplot, **kwargs)
            ffig.show_grayscale(stretch='arcsinh')
    return ffig

# %%
plot_cutout(stamp)
# Out:
# WARNING: No WCS information found in header - using pixel coordinates [aplpy.header]
# INFO: Auto-setting vmin to  9.115e+01 [aplpy.core]
# INFO: Auto-setting vmax to  1.032e+03 [aplpy.core]

# %% [markdown]
# Now let's make a nice helper function:

# %%
def show_stamps(packet):
    #fig, axes = plt.subplots(1,3, figsize=(12,4))
    fig = plt.figure(figsize=(12,4))
    for i, cutout in enumerate(['Science','Template','Difference']):
        stamp = packet['cutout{}'.format(cutout)]['stampData']
        ffig = plot_cutout(stamp, fig=fig, subplot = (1,3,i+1))
        ffig.set_title(cutout)

# %%
show_stamps(packet)
# Out:
# WARNING: No WCS information found in header - using pixel coordinates [aplpy.header]
# INFO: Auto-setting vmin to  9.115e+01 [aplpy.core]
# INFO: Auto-setting vmax to  1.032e+03 [aplpy.core]
# WARNING: No WCS information found in header - using pixel coordinates [aplpy.header]
# INFO: Auto-setting vmin to  1.040e+02 [aplpy.core]
# INFO: Auto-setting vmax to  1.018e+03 [aplpy.core]
# WARNING: No WCS information found in header - using pixel coordinates [aplpy.header]
# INFO: Auto-setting vmin to -1.957e+01 [aplpy.core]
# INFO: Auto-setting vmax to  4.050e+01 [aplpy.core]
